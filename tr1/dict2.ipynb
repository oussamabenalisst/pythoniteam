# %%
def ajout_jeu(collection,namejeu,annee,edit,genre):
    collection[namejeu]={"annee":annee,"editere":edit,"genre":genre}

def mettre_jour_information(collection):
    namejeu=input("donne nom de jeu : ")
    while not  namejeu in collection.keys():
        namejeu=input("donne nom de jeu : ")
    annee=input("donne annee : ")
    while not annee.isdigit() : 
        annee=input("donne annee : ")
    edit=input("donne editere : ")
    while not edit.isalpha() :
        edit=input("donne editere : ")
    genre=input("donne genre : ")
    while not genre.isalpha() :
        genre=input("donne genre : ")
    collection[namejeu]={"annee":annee,"editere":edit,"genre":genre}

def supprimer_jour(collection):
    namejeu=input("donne nom de jeu : ")
    while not namejeu in collection.keys():
        namejeu=input("donne nom de jeu : ")
    del collection[namejeu]
    print(f"{namejeu} supp avac succés")

def afficher_jour(collection,r):
    for v,k in collection.items():
        print(f"-------------------{r}------------------------")
        print(f"nom du jeu : {v}")
        print(f"annee : {k['annee']}")
        print(f"editeur : {k['editere']}")
        print(f"genre : {k['genre']}")

def recherch_par_genre(collection,genre):
    test=False
    for k,v in collection.items():
        if v['genre']==genre : 
            test=True 
            print(f"nom du jeu : {k}")
            print(f"annee : {v['annee']}")
            print(f"editeur : {v['editere']}")
            print(f"genre : {v['genre']}")
    if test :
        print(f"aucun jeu trouvé avec le genre : {genre}")

#******************prpr*******************#
collection={}
n=input("donner le nombre de jeu : ")
while not n.isdigit() or int(n)<0 :
    n=input("donner le nombre de jeu : ")
for i in range(int(n)):
    namejeu=input("donne nom de jeu : ")
    annee=input("donne annee : ")
    while not annee.isdigit() : 
        annee=input("donne annee : ")
    edit=input("donne editere : ")
    while not edit.isalpha() :
        edit=input("donne editere : ")
    genre=input("donne genre : ")
    while not genre.isalpha() :
        genre=input("donne genre : ") 
    ajout_jeu(collection,namejeu,annee,edit,genre)
afficher_jour(collection,"ajou")
mettre_jour_information(collection)
afficher_jour(collection,"mettreajour")
supprimer_jour(collection)
genre=input("donne genre : ")
while not genre.isalpha() :
    genre=input("donne genre : ")
recherch_par_genre(collection,genre)
# Out:
# -------------------ajou------------------------
# nom du jeu : reded
# annee : 2019
# editeur : rec
# genre : serva
# -------------------ajou------------------------
# nom du jeu : dddd
# annee : 1545
# editeur : qsdqs
# genre : dsqdqs
# -------------------mettreajour------------------------
# nom du jeu : reded
# annee : 2019
# editeur : rec
# genre : serva
# -------------------mettreajour------------------------
# nom du jeu : dddd
# annee : 2000
# editeur : putin
# genre : reded
# dddd supp avac succés

# %%
def change_color(vehicule,color,car):
    if car in vehicule.keys():
        vehicule[car]["color"]=color
    else:
        print(f"le {car} n'existe pas")

#*************prprp************************
#*************prprp************************
#*************prprp************************
vehicule={
    "Panama":{
        "color":"red",
        "vitesse":1500,
        "annee":2000,
    },
    "AEgypt":{
        "color":"blue",
        "vitesse":2000,
        "annee":2010,
    }
}
car=input("donne nom du car : ")
color=input("donne color : ")

change_color(vehicule,color,car)
