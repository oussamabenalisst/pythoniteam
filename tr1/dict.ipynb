# %%
def calculer_total_vents(ventes):
    total=0
    for v in ventes.values():
        total+=v
    return total

def trouver_mois_max_ventes(ventes):
    max_v=0
    for v in ventes.values():
        if v>max_v:
            max_v=v
    return max_v



def ajout_mois(ventes,m,n):
    ventes[n]=m


#?!!!!!!!!program pransipal!!!!!!!!!!!!!!!
manth=["janvier", "fevrier", "mars", "avril", "mai","juin", "juillet", "aout", "september", "october", "novembre", "december"]
ventes={
    "janvier":float(input("donne le montant 1 : ")),
    "fevrier":float(input("donne le montant 2 : ")),
    "mars":float(input("donne le montant 3 : ")),
    "avril":float(input("donne le montant 4 : ")),
    "may":float(input("donne le montant 5 : ")),
    "juin":float(input("donne le montant 6 : ")),

}

print("la somme total de ventes est",calculer_total_vents(ventes))
print("le maximale de ventes est",trouver_mois_max_ventes(ventes))

#???????????????controller???????????????????
#???????????????controller???????????????????
#???????????????controller???????????????????
#>>>  control de mois    
mois=input("donne voter mois")
while not mois.isalpha() or mois in ventes or not mois in manth :
    mois=input("donne voter mois")
#>>>   control de montant  
montant=input("donne montant : ")
while montant.find(".")==-1 or not montant[:montant.find(".")].isdigit() or not montant[montant.find(".")+1:len(montant)].isdigit():
    montant=input("donne montant : ")
#???????????????controller???????????????????
#???????????????controller???????????????????
#???????????????controller???????????????????
ajout_mois(ventes,float(montant),mois)
print("_______________ enrg _____________")
for k,v in ventes.items():
    print("le montant de ",k," est ",v)
print("_______________ enrg _____________")
# Out:
# la somme total de ventes est 287.0
# le maximale de ventes est 254.0
# _______________ enrg _____________
# le montant de  janvier  est  1.0
# le montant de  fevrier  est  2.0
# le montant de  mars  est  5.0
# le montant de  avril  est  10.0
# le montant de  may  est  15.0
# le montant de  juin  est  254.0
# le montant de  october  est  123.5
# _______________ enrg _____________

# %%
def ajout_etudiant(notes,name,note):
    notes[name.title()]=float(note)
    
def afficher_notes(notes):
    for name,note in notes.items():
        print(f"le nom de {name} est {note}")


def moyenne_classe(notes):
    total=0
    for note in notes.values():
        total+=note
    return total/len(notes)

    


def suppress_etudiant(notes,name):
    del notes[name]
# ---------------------program prancpal

notes={
    "Myra Martin":7.1931,
    "Jason Rhodes":11.5321,
    "Lou Armstrong":14.2271,
    "Lois Cummings":18.9281,
    "Phoebe Burns":19.1647
}
afficher_notes(notes)
print("---------------------ajou----------------------------------")

name=input("donne name : ")
while name.find(" ")==-1 or not name[:name.find(" ")].isalpha() or not name[name.find(" ")+1:len(name)].isalpha() : 
    name=input("donne name : ")
note=input("donne note : ")
while note.find(".")==-1 or not note[:note.find(".")].isdigit() or not note[note.find(".")+1:len(note)].isdigit() or int(note[:note.find(".")])>20 :
    note=input("donne note : ")
ajout_etudiant(notes,name,note)
afficher_notes(notes)

print("le moyenne de la classe est ",moyenne_classe(notes))


name=input("donne name : ")
while name.find(" ")==-1 or not name[:name.find(" ")].isalpha() or not name[name.find(" ")+1:len(name)].isalpha() or not name in notes : 
    name=input("donne name : ")
suppress_etudiant(notes,name)
print("------------------apres suppress---------------------------------")
afficher_notes(notes)
# Out:
# le nom de  Myra Martin  est  7.1931
# le nom de  Jason Rhodes  est  11.5321
# le nom de  Lou Armstrong  est  14.2271
# le nom de  Lois Cummings  est  18.9281
# le nom de  Phoebe Burns  est  19.1647
# ---------------------ajou----------------------------------
# le nom de  Myra Martin  est  7.1931
# le nom de  Jason Rhodes  est  11.5321
# le nom de  Lou Armstrong  est  14.2271
# le nom de  Lois Cummings  est  18.9281
# le nom de  Phoebe Burns  est  19.1647
# le nom de  Oussama Benali  est  12.5555
# le moyenne de la classe est  13.933433333333333
# ------------------apres suppress---------------------------------
# le nom de  Myra Martin  est  7.1931
# le nom de  Jason Rhodes  est  11.5321
# le nom de  Lois Cummings  est  18.9281
# le nom de  Phoebe Burns  est  19.1647
# le nom de  Oussama Benali  est  12.5555

# %%
import random 
t=[]
for i in range(2):
    t.append({
        "name" : input("donne nom : ") ,
        "age" :  random.randint(1,100) ,
    })
for i in range(len(t)) :
    for v,k in t[i].items():
        print(v,":" ,k)
print(t)
# Out:
# name : oussama benali
# age : 98
# name : oussa
# age : 6
# [{'name': 'oussama benali', 'age': 98}, {'name': 'oussa', 'age': 6}]

# %%
def recherch(car,name):
    i=0
    while i<len(car) and car[i]["marquee"]!=name:
        i+=1
    return i

def change_color(car,name,color):
    i=recherch(car,name)
    car[i]["color"]=color

def neuve(car,name,color):
    if recherch(car,name)==len(car):
        print("")
