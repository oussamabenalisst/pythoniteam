# %%
import pandas as pd

df=pd.read_csv('./sample_data_simple_id.csv' , index_col=0)
df=pd.read_csv('./sample_data_simple_id.csv' , header=None)

print(df)
# Out:
#            0        1    2
# 0         ID     NAME  AGE
# 1          1    Fiona   78
# 2          2   Hannah   80
# 3          3   Hannah   32
# 4          4  Charlie   51
# ...      ...      ...  ...
# 9996    9996   George   79
# 9997    9997   George   57
# 9998    9998    Alice   22
# 9999    9999      Ian   80
# 10000  10000  Charlie   64
#
# [10001 rows x 3 columns]

# %%
df=pd.read_csv('./sample_data_simple_id.csv' , names=('a', 'b', 'c'))

print(df.to_string())
# Out:
#            a        b    c
# 0         ID     NAME  AGE
# 1          1    Fiona   78
# 2          2   Hannah   80
# 3          3   Hannah   32
# 4          4  Charlie   51
# 5          5    Julia   48
# 6          6    David   61
# 7          7      Ian   37
# 8          8   Hannah   35
# 9          9    Alice   42
# 10        10    Fiona   35
# 11        11    Alice   20
# 12        12      Bob   74
# 13        13      Bob   47
# 14        14    Alice   49
# 15        15    Julia   27
# 16        16    Fiona   53
# 17        17    Julia   74
# 18        18   George   52
# 19        19    Julia   20
# 20        20    Fiona   20
# 21        21      Bob   24
# 22        22   George   78
# 23        23   Hannah   33
# 24        24      Ian   45
# 25        25      Bob   61
# 26        26      Bob   52
# 27        27    Julia   28
# 28        28     Emma   67
# 29        29   George   50
# 30        30      Ian   36
# 31        31   George   26
# 32        32     Emma   39
# ...

# %%
df=pd.read_csv('./sample_data_simple_id.csv' , header=0)

print(df)
df=pd.read_csv('./sample_data_simple_id.csv' , header=2)

print(df)
# Out:
#          ID     NAME  AGE
# 0         1    Fiona   78
# 1         2   Hannah   80
# 2         3   Hannah   32
# 3         4  Charlie   51
# 4         5    Julia   48
# ...     ...      ...  ...
# 9995   9996   George   79
# 9996   9997   George   57
# 9997   9998    Alice   22
# 9998   9999      Ian   80
# 9999  10000  Charlie   64
#
# [10000 rows x 3 columns]
#           2   Hannah  80
# 0         3   Hannah  32
# 1         4  Charlie  51
# 2         5    Julia  48
# 3         6    David  61
# 4         7      Ian  37
# ...     ...      ...  ..
# 9993   9996   George  79
# 9994   9997   George  57
# 9995   9998    Alice  22
# 9996   9999      Ian  80
# 9997  10000  Charlie  64
#
# [9998 rows x 3 columns]

# %%
print(pd.options.display.max_rows)
pd.options.display.max_rows=99
print(pd.options.display.max_rows)
# Out:
# 99
# 99

# %%
import xlrd 

# df=pd.read_excel('./sample_data.xlsx')
df=pd.read_excel('./sample_data.xlsx' , sheet_name=0)


print(df)
# Out:
#        ID         NAME  AGE
# 0       1     Person_1    1
# 1       2     Person_2    2
# 2       3     Person_3    3
# 3       4     Person_4    4
# 4       5     Person_5    5
# ..    ...          ...  ...
# 995   996   Person_996   96
# 996   997   Person_997   97
# 997   998   Person_998   98
# 998   999   Person_999   99
# 999  1000  Person_1000    0
#
# [1000 rows x 3 columns]
